# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import time

# %%
# creamos my_stata_reader, un objeto que nos permite leer por chunks (trozos)
# encoding utf-8
my_stata_reader = pd.read_stata('data/BID2.EMPRESAS.dta', chunksize=10)
my_stata_reader._encoding = 'utf-8'

# %%
my_stata_reader.variable_labels()
# Out:
# {'id': 'ID',
#  'id_empresa': 'ID_EMPRESA',
#  'tipo_persona': 'TIPO_PERSONA',
#  'tipo_sociedad': 'TIPO_SOCIEDAD',
#  'descripcion_empresa': 'DESCRIPCION_EMPRESA',
#  'actividad': 'ACTIVIDAD',
#  'tipo_empleador': 'TIPO_EMPLEADOR',
#  'como_se_entero_del_sne': 'COMO_SE_ENTERO_DEL_SNE',
#  'entidadfed_sne': 'ENTIDADFED_SNE',
#  'municipio': 'MUNICIPIO',
#  'localidad': 'LOCALIDAD',
#  'codigo_postal': 'CODIGO_POSTAL',
#  'fuente': 'FUENTE'}

# %%
a = my_stata_reader.get_chunk()
a.head(3)
# Out:
#        id  id_empresa tipo_persona tipo_sociedad  \
# 0  123996       301.0       FISICA        FISICA
# 1  242786      1201.0       FISICA        FISICA
# 2   43691      1301.0       FISICA        FISICA
#
#                                  descripcion_empresa  \
# 0                          SERVICIOS DE CONTABILIDAD
# 1  ENVASADO Y COMERCIALIZACION DE DETERGENTES Y M...
# 2                        CENTRO DE IMPRESION DIGITAL
#
#                                            actividad tipo_empleador  \
# 0  Servicios de contabilidad, auditoría y servici...        PRIVADA
# 1            Servicios de administración de negocios        PRIVADA
# 2  Servicios de publicidad y actividades relacion...        PRIVADA
#
#   como_se_entero_del_sne   entidadfed_sne                    municipio  \
# 0               Internet          DURANGO                GÓMEZ PALACIO
# 1               Internet  SAN LUIS POTOSÍ  SOLEDAD DE GRACIANO SÁNCHEZ
# 2               Internet  SAN LUIS POTOSÍ  SOLEDAD DE GRACIANO SÁNCHEZ
#
#                      localidad codigo_postal   fuente
# 0                GÓMEZ PALACIO         35000  SISPAEW
# 1  SOLEDAD DE GRACIANO SÁNCHEZ         78433  SISPAEW
# 2  SOLEDAD DE GRACIANO SÁNCHEZ         78438  SISPAEW

# %%
# define which columns will be written
my_stata_reader = pd.read_stata('data/BID2.EMPRESAS.dta', chunksize=10000, 
                               columns=['id_empresa', 'tipo_persona', 'tipo_sociedad', 'descripcion_empresa',
                               'actividad', 'tipo_empleador'])
# encoding
my_stata_reader._encoding = 'utf-8'

# get columns names and write them in CSV file
my_string = ",".join(my_stata_reader.variable_labels() )    

# ‘r’ read. ‘w’ write. ‘a’ append. ‘r+’ read and write mode, which is used to handle both actions.
with open('empresas.csv','w') as file:
    file.write(my_string)   
    file.write('\n')

# %%
# start y end medirán el tiempo
start = time.time()
first = True
# para cada chunk, hará lo siguiente:
for chunk in my_stata_reader:
    if first:
        chunk.to_csv('empresas.csv', mode='w', index=False, header=True)   #‘w’ write a new file
        first = False
    else: 
        chunk.to_csv('empresas.csv', mode='a', index=False, header=False)   #‘a’ append.
    # imprimir un punto cada que anexa un chunk
    print('.', end = '')
end = time.time()
print (('Total time: ') + str(end - start))
# Out:
# ....................Total time: 2.842252492904663

# %%
# Verifiquemos el tamanio del CSV
filesize= os.stat('empresas.csv').st_size
print(filesize)
# Out:
# 26333161

# %%
empresas = pd.read_csv('empresas.csv')
empresas.head()
# Out:
#    id_empresa tipo_persona tipo_sociedad  \
# 0       301.0       FISICA        FISICA
# 1      1201.0       FISICA        FISICA
# 2      1301.0       FISICA        FISICA
# 3      1701.0       FISICA        FISICA
# 4      1801.0       FISICA        FISICA
#
#                                  descripcion_empresa  \
# 0                          SERVICIOS DE CONTABILIDAD
# 1  ENVASADO Y COMERCIALIZACION DE DETERGENTES Y M...
# 2                        CENTRO DE IMPRESION DIGITAL
# 3                     ABOGADOS Y ATENCION A CLIENTES
# 4                                              TAXIS
#
#                                            actividad tipo_empleador
# 0  Servicios de contabilidad, auditoría y servici...        PRIVADA
# 1            Servicios de administración de negocios        PRIVADA
# 2  Servicios de publicidad y actividades relacion...        PRIVADA
# 3                                  Servicios legales        PRIVADA
# 4     Otros servicios relacionados con el transporte        PRIVADA

# %% [markdown]
# ## Exploring the table

# %%
empresas.shape
# Out:
# (193551, 6)

# %%
empresas.nunique()
# Out:
# id_empresa             193551
# tipo_persona                2
# tipo_sociedad              10
# descripcion_empresa    125198
# actividad                 600
# tipo_empleador              3
# dtype: int64

# %%
empresas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193551 entries, 0 to 193550
# Data columns (total 6 columns):
# id_empresa             193551 non-null float64
# tipo_persona           193551 non-null object
# tipo_sociedad          193551 non-null object
# descripcion_empresa    192942 non-null object
# actividad              193551 non-null object
# tipo_empleador         193551 non-null object
# dtypes: float64(1), object(5)
# memory usage: 8.9+ MB

# %%
empresas['tipo_persona'].unique()
# Out:
# array(['FISICA', 'MORAL'], dtype=object)

# %%
empresas['tipo_sociedad'].unique()
# Out:
# array(['FISICA', 'S.A. DE C.V.', 'S.C.', 'A.C.', 'S. de R.L. de C.V.',
#        'S.A.', 'S. de R.L.', 'S. de R.L. de I.P.', 'S.A. P.I. de C.V.',
#        'S.A. de C.V. de M.I.'], dtype=object)

# %%
empresas['actividad'].nunique()
# Out:
# 600

# %%
empresas['actividad'].unique()
# Out:
# array(['Servicios de contabilidad, auditoría y servicios relacionados',
#        'Servicios de administración de negocios',
#        'Servicios de publicidad y actividades relacionadas',
#        'Servicios legales',
#        'Otros servicios relacionados con el transporte',
#        'Industria del sonido', 'Guarderías',
#        'Comercio al por mayor de abarrotes y alimentos',
#        'Comercio al por menor en tiendas de autoservicio',
#        'Agencias de viajes y servicios de reservaciones',
#        'Escuelas de educación básica, media y para necesidades especiales',
#        'Servicios de almacenamiento', 'Curtido y acabado de cuero y piel',
#        'Comercio al por menor de abarrotes y alimentos',
#        'Salones y clínicas de belleza, baños públicos y bolerías',
#        'FABRICACION DE PRENDAS DE VESTIR DE PUNTO',
#        'OTROS SERVICIOS DE APOYO A LOS NEGOCIOS',
#        'SERVICIOS DE INVESTIGACION CIENTIFICA Y DESARROLLO',
#        'Confección de prendas de vestir', 'CONSULTORIOS MEDICOS',
#        'OTRAS INDUSTRIAS ALIMENTARIAS',
#        'OTROS SERVICIOS DE TELECOMUNICACIONES', 'EDIFICACION RESIDENCIAL',
#        'Alquiler de artículos para el hogar y personales',
#        'Consultorios dentales', 'Otros servicios de apoyo a los negocios',
#        'Comercio al por menor de mobiliario, equipo y accesorios de cómputo, teléfonos y otros aparatos de comunicación',
#        'Comercio al por menor de partes y refacciones para automóviles, camionetas y camiones',
#        'Servicios de investigación científica y desarrollo',
#        'Impresión e industrias conexas',
#        'Reparación y mantenimiento de artículos para el hogar y personales',
#        'Otros servicios educativos',
#        'SERVICIOS DE CONTABILIDAD, AUDITORIA Y SERVICIOS RELACIONADOS',
#        'Servicios de consultoría administrativa, científica y técnica',
#        'Reparación y mantenimiento de equipo electrónico y de equipo de precisión',
#        'CORPORATIVOS', 'Restaurantes con servicio completo',
#        'Transporte colectivo foráneo de pasajeros de ruta fija',
#        'Servicios relacionados con el transporte por ferrocarril',
#        'Comercio al por menor de artículos de ferretería, tlapalería y vidrios',
#        'Comercio al por mayor de materias primas para la industria',
#        'Comercio al por menor de artículos de papelería, libros, revistas y periódicos',
#        'OTROS SERVICIOS PROFESIONALES, CIENTIFICOS Y TECNICOS',
#        'Servicios relacionados con los seguros y las fianzas',
#        'INTERMEDIACION DE COMERCIO AL POR MAYOR, EXCEPTO A TRAVES DE INTERNET Y DE OTROS MEDIOS ELECTRONICOS',
#        'Comercio al por mayor de mobiliario y equipo de cómputo y de oficina, y de otra maquinaria y equipo de uso general',
#        'ALQUILER DE MAQUINARIA Y EQUIPO AGROPECUARIO, PESQUERO, INDUSTRIAL, COMERCIAL Y DE SERVICIOS',
#        'Asociaciones y organizaciones comerciales, laborales, profesionales y recreativas',
#        'Fabricación de cemento y productos de concreto',
#        'Alquiler de maquinaria y equipo agropecuario, pesquero, industrial, comercial y de servicios',
#        'FABRICACION DE PRODUCTOS QUIMICOS BASICOS',
#        'SERVICIOS DE ADMINISTRACION DE NEGOCIOS',
#        'Fabricación de laminados y aglutinados de madera',
#        'Otros servicios de telecomunicaciones',
#        'Fabricación de prendas de vestir de punto',
#        'FABRICACION DE RESINAS Y HULES SINTETICOS, Y FIBRAS QUIMICAS',
#        'Comercio al por mayor de productos textiles y calzado',
#        'Servicios de apoyo a la educación',
#        'CONSTRUCCION DE OBRAS PARA EL SUMINISTRO DE AGUA, PETROLEO, GAS, ENERGIA ELECTRICA Y TELECOMUNICACIONES',
#        'FABRICACION DE OTRA MAQUINARIA Y EQUIPO PARA LA INDUSTRIA EN GENERAL',
#        'OTROS SERVICIOS RECREATIVOS',
#        'AUTOTRANSPORTE DE CARGA ESPECIALIZADO',
#        'Fabricación de muebles, excepto de oficina y estantería',
#        'Comercio al por mayor de artículos de papelería, libros, revistas y periódicos',
#        'Servicios relacionados con la cría y explotación de animales',
#        'Escuelas comerciales, de computación y de capacitación para ejecutivos',
#        'Servicios funerarios y administración de cementerios',
#        'Fabricación de muebles de oficina y estantería',
#        'ASOCIACIONES Y ORGANIZACIONES COMERCIALES, LABORALES, PROFESIONALES Y RECREATIVAS',
#        'Servicio de apoyo secretarial, fotocopiado, cobranza, investigación crediticia y similares',
#        'COMERCIO AL POR MENOR DE ABARROTES Y ALIMENTOS',
#        'FABRICACION DE PRODUCTOS DE CARTON Y PAPEL',
#        'Hoteles, moteles y similares', 'HOTELES, MOTELES Y SIMILARES',
#        'Servicios de capacitación para el trabajo para personas desempleadas, subempleadas o discapacitadas',
#        'Fabricación de equipo aeroespacial',
#        'Comercio al por menor de artículos para el cuidado de la salud',
#        'Trabajos de acabados en edificaciones',
#        'Servicios de investigación, protección y seguridad',
#        'Laboratorios médicos y de diagnóstico',
#        'Comercio al por mayor de artículos de perfumería, cosméticos y joyería',
#        'COMERCIO AL POR MENOR EN TIENDAS DE AUTOSERVICIO',
#        'Servicios de revelado e impresión de fotografías y otros servicios personales',
#        'Fabricación de calderas, tanques y envases metálicos',
#        'Fabricación de partes para vehículos automotores',
#        'Comercio al por menor de mascotas, regalos, artículos religiosos, desechables y otros artículos de uso personal',
#        'Escuelas de educación superior',
#        'Fabricación de automóviles y camiones', 'FABRICACION DE TELAS',
#        'Escuelas de oficios',
#        'Reparación y mantenimiento de automóviles y camiones',
#        'COMERCIO AL POR MENOR EN TIENDAS DEPARTAMENTALES',
#        'FABRICACION DE OTROS PRODUCTOS METALICOS',
#        'Confección de accesorios de vestir y otras prendas de vestir no clasificados en otra parte',
#        'Elaboración de productos lácteos',
#        'COMERCIO AL POR MAYOR DE ARTICULOS DE PAPELERIA, LIBROS, REVISTAS Y PERIODICOS',
#        'RESTAURANTES CON SERVICIO COMPLETO',
#        'SERVICIOS DE CONSULTORIA ADMINISTRATIVA, CIENTIFICA Y TECNICA',
#        'SERVICIOS DE APOYO A LA EDUCACION',
#        'Comercio al por menor de ropa, bisutería y accesorios de vestir',
#        'Otros servicios profesionales, científicos y técnicos',
#        'Inmobiliarias y corredores de bienes raíces',
#        'Comercio al por menor de motocicletas y otros vehículos de motor',
#        'MAQUINADO DE PIEZAS METALICAS Y FABRICACION DE TORNILLOS',
#        'Corporativos', 'Servicios de limpieza',
#        'COMERCIO AL POR MENOR DE ARTICULOS PARA EL ESPARCIMIENTO',
#        'Administración pública en general',
#        'Servicios de diseño de sistemas de cómputo y servicios relacionados',
#        'Consultorios médicos', 'FABRICACION DE PULPA, PAPEL Y CARTON',
#        'REPARACION Y MANTENIMIENTO DE MAQUINARIA Y EQUIPO AGROPECUARIO, INDUSTRIAL, COMERCIAL Y DE SERVICIOS',
#        'Fabricación de otros productos metálicos',
#        'ADMINISTRACION PUBLICA EN GENERAL',
#        'Comercio al por menor de muebles para el hogar y otros enseres domésticos',
#        'Servicios de enfermería a domicilio',
#        'EDICION DE SOFTWARE Y EDICION DE SOFTWARE INTEGRADA CON LA REPRODUCCION',
#        'Restaurantes de autoservicio, comida para llevar y otros restaurantes con servicio limitado',
#        'Comercio al por mayor de productos farmacéuticos',
#        'AUTOTRANSPORTE DE CARGA GENERAL', 'Diseño especializado',
#        'Otras industrias manufactureras',
#        'COMERCIO AL POR MAYOR DE ARTICULOS DE PERFUMERIA, COSMETICOS Y JOYERIA',
#        'COMERCIO AL POR MENOR DE ARTICULOS DE FERRETERIA, TLAPALERIA Y VIDRIOS',
#        'SERVICIOS DE ALMACENAMIENTO', 'Otras industrias alimentarias',
#        'OTRAS INDUSTRIAS MANUFACTURERAS',
#        'OPERADORES DE TELECOMUNICACIONES INALAMBRICAS, EXCEPTO SERVICIOS DE SATELITE',
#        'COMERCIO AL POR MAYOR DE PRODUCTOS FARMACEUTICOS',
#        'Otras instituciones de intermediación crediticia y financiera no bursátil',
#        'Otros consultorios para el cuidado de la salud',
#        'COMERCIO AL POR MAYOR DE MOBILIARIO Y EQUIPO DE COMPUTO Y DE OFICINA, Y DE OTRA MAQUINARIA Y EQUIPO DE USO GENERAL',
#        'Autotransporte de carga general', 'INDUSTRIA DE LAS BEBIDAS',
#        'Reparación y mantenimiento de maquinaria y equipo agropecuario, industrial, comercial y de servicios',
#        'Elaboración de productos de panadería y tortillas',
#        'FABRICACION DE OTROS PRODUCTOS TEXTILES, EXCEPTO PRENDAS DE VESTIR',
#        'Comercio al por menor de calzado',
#        'FABRICACION DE PRODUCTOS DE PLASTICO',
#        'COMERCIO AL POR MAYOR DE ABARROTES Y ALIMENTOS',
#        'Comercio al por menor de artículos para la decoración de interiores',
#        'Construcción de obras para el suministro de agua, petróleo, gas, energía eléctrica y telecomunicaciones',
#        'Comercio al por menor de combustibles, aceites y grasas lubricantes',
#        'IMPRESION E INDUSTRIAS CONEXAS',
#        'Transporte colectivo urbano y suburbano de pasajeros de ruta fija',
#        'Comercio al por mayor de discos, juguetes y artículos deportivos',
#        'Comercio al por mayor de electrodomésticos menores y aparatos de línea blanca',
#        'Fabricación de productos químicos básicos',
#        'FABRICACION DE COMPUTADORAS Y EQUIPO PERIFERICO',
#        'SERVICIOS RELACIONADOS CON LOS SERVICIOS INMOBILIARIOS',
#        'Fabricación de otros productos de madera',
#        'OTRAS CONSTRUCCIONES DE INGENIERIA CIVIL',
#        'Comercio al por menor de bebidas, hielo y tabaco',
#        'GENERACION, TRANSMISION Y DISTRIBUCION DE ENERGIA ELECTRICA',
#        'FABRICACION DE OTROS PRODUCTOS DE MADERA',
#        'Instalaciones y equipamiento en construcciones',
#        'Comercio al por mayor de maquinaria y equipo agropecuario, forestal y para la pesca',
#        'HOSPITALES DE OTRAS ESPECIALIDADES MEDICAS',
#        'Instituciones financieras de fomento económico',
#        'Otras construcciones de ingeniería civil',
#        'Comercio al por mayor de bebidas, hielo y tabaco',
#        'Fabricación de pulpa, papel y cartón',
#        'COMERCIO AL POR MENOR DE ARTICULOS DE PAPELERIA, LIBROS, REVISTAS Y PERIODICOS',
#        'Comercio al por menor de artículos de perfumería y joyería',
#        'Fabricación de vidrio y productos de vidrio',
#        'Comercio al por menor exclusivamente a través de internet, y catálogos impresos, televisión y similares',
#        'Servicios de empleo', 'Instituciones de seguros y fianzas',
#        'Comercio al por menor de artículos para el esparcimiento',
#        'Fabricación de productos de plástico',
#        'LAVANDERIAS Y TINTORERIAS', 'Otros servicios de información',
#        'Industria básica del aluminio',
#        'SERVICIOS DE DISEÑO DE SISTEMAS DE COMPUTO Y SERVICIOS RELACIONADOS',
#        'Fabricación de otros productos textiles, excepto prendas de vestir',
#        'Fabricación de resinas y hules sintéticos, y fibras químicas',
#        'Servicios de orientación y trabajo social',
#        'Comercio al por mayor de camiones y de partes y refacciones nuevas para automóviles, camionetas y camiones',
#        'Construcción de vías de comunicación',
#        'Edición de periódicos, revistas, libros y similares, y edición de estas publicaciones integrada con la impresión',
#        'OTROS SERVICIOS DE INFORMACION', 'SERVICIOS DE LIMPIEZA',
#        'Museos, sitios históricos, zoológicos y similares',
#        'OTROS TRABAJOS ESPECIALIZADOS PARA LA CONSTRUCCION',
#        'CONFECCION DE PRENDAS DE VESTIR',
#        'FABRICACION DE MAQUINARIA Y EQUIPO PARA LA INDUSTRIA METALMECANICA',
#        'INDUSTRIA BASICA DEL HIERRO Y DEL ACERO',
#        'Servicio de taxis y limusinas',
#        'Pensiones y casas de huéspedes, y departamentos y casas amueblados con servicios de hotelería',
#        'Comercio al por mayor de maquinaria y equipo para los servicios y para actividades comerciales',
#        'Fabricación de calzado',
#        'Comercio al por menor de productos textiles, excepto ropa',
#        'FABRICACION DE PRODUCTOS FARMACEUTICOS',
#        'Comercio al por menor en tiendas departamentales',
#        'Fabricación de productos de hule',
#        'Servicios relacionados con el transporte aéreo',
#        'SERVICIOS RELACIONADOS CON LOS SEGUROS Y LAS FIANZAS',
#        'Cimentaciones, montaje de estructuras prefabricadas y trabajos en exteriores',
#        'EXPLOTACION DE BOVINOS',
#        'Fabricación de componentes electrónicos',
#        'Fabricación de maquinaria y equipo para la industria metalmecánica',
#        'Elaboración de alimentos para animales',
#        'REPARACION Y MANTENIMIENTO DE EQUIPO ELECTRONICO Y DE EQUIPO DE PRECISION',
#        'Comercio al por mayor de maquinaria y equipo para la industria',
#        'Centros generales de alquiler',
#        'SERVICIOS DE MENSAJERIA Y PAQUETERIA LOCAL',
#        'Campamentos y albergues recreativos',
#        'Fabricación de estructuras metálicas y productos de herrería',
#        'Servicios de telecomunicaciones por satélite',
#        'OTROS SERVICIOS RELACIONADOS CON EL TRANSPORTE',
#        'Cultivo de frutales y nueces',
#        'Fabricación de productos de hierro y acero',
#        'Actividades administrativas de instituciones de bienestar social',
#        'Servicios comunitarios de alimentación, refugio y emergencia',
#        'Otros trabajos especializados para la construcción',
#        'Comercio al por menor de automóviles y camionetas',
#        'SERVICIOS DE PREPARACION DE ALIMENTOS POR ENCARGO',
#        'Lavanderías y tintorerías',
#        'Transmisión de programas de radio y televisión',
#        'COMERCIO AL POR MENOR DE AUTOMOVILES Y CAMIONETAS',
#        'Conservación de frutas, verduras y alimentos preparados',
#        'Hospitales generales', 'ELABORACION DE PRODUCTOS LACTEOS',
#        'TRANSPORTE AEREO REGULAR',
#        'Maquinado de piezas metálicas y fabricación de tornillos',
#        'Alquiler sin intermediación de bienes raíces',
#        'Servicios relacionados con el transporte por carretera',
#        'SERVICIOS COMUNITARIOS DE ALIMENTACION, REFUGIO Y EMERGENCIA',
#        'SERVICIOS DE EMPLEO',
#        'Preparación e hilado de fibras textiles, y fabricación de hilos',
#        'Fabricación de herrajes y cerraduras',
#        'Servicios de ambulancias, de bancos de órganos y otros servicios auxiliares al tratamiento médico',
#        'FABRICACION DE PRODUCTOS DERIVADOS DEL PETROLEO Y DEL CARBON',
#        'Industria fílmica y del video',
#        'Fabricación de otros productos químicos',
#        'Edificación no residencial',
#        'TRABAJOS DE ACABADOS EN EDIFICACIONES',
#        'COMERCIO AL POR MENOR DE MUEBLES PARA EL HOGAR Y OTROS ENSERES DOMESTICOS',
#        'Servicios combinados de apoyo en instalaciones',
#        'Centros para la atención de pacientes que no requieren hospitalización',
#        'Otros servicios recreativos',
#        'Fabricación de equipo de comunicación',
#        'Servicios de preparación de alimentos por encargo',
#        'COMERCIO AL POR MAYOR DE BEBIDAS, HIELO Y TABACO',
#        'COMERCIO AL POR MENOR DE ARTICULOS PARA LA DECORACION DE INTERIORES',
#        'RESTAURANTES DE AUTOSERVICIO, COMIDA PARA LLEVAR Y OTROS RESTAURANTES CON SERVICIO LIMITADO',
#        'Servicios relacionados con los servicios inmobiliarios',
#        'Fabricación de maquinaria y equipo para las industrias manufactureras, excepto la metalmecánica',
#        'OTROS SERVICIOS EDUCATIVOS', 'Industria de las bebidas',
#        'FABRICACION DE OTROS PRODUCTOS QUIMICOS',
#        'ESCUELAS DE EDUCACION SUPERIOR',
#        'Servicios relacionados con el aprovechamiento forestal',
#        'Alquiler de automóviles, camiones y otros transportes terrestres',
#        'Transporte escolar y de personal',
#        'Asesoría en inversiones y otros servicios relacionados con la intermediación bursátil',
#        'Transporte turístico por tierra',
#        'Fabricación de otros equipos y accesorios eléctricos',
#        'Comercio al por mayor de materias primas agropecuarias y forestales',
#        'FABRICACION DE MUEBLES, EXCEPTO DE OFICINA Y ESTANTERIA',
#        'COMERCIO AL POR MENOR DE ROPA, BISUTERIA Y ACCESORIOS DE VESTIR',
#        'Aserrado y conservación de la madera',
#        'Actividades de seguridad nacional',
#        'Acabado de productos textiles y fabricación de telas recubiertas',
#        'Hospitales de otras especialidades médicas',
#        'Asociaciones y organizaciones religiosas, políticas y civiles',
#        'Compañías y grupos de espectáculos artísticos y culturales',
#        'Fabricación de fertilizantes, pesticidas y otros agroquímicos',
#        'Preparación y envasado de pescados y mariscos',
#        'Fabricación de otros productos de cuero, piel y materiales sucedáneos',
#        'Deportistas y equipos deportivos profesionales',
#        'Servicios de mensajería y paquetería local',
#        'Uniones de crédito e instituciones de ahorro',
#        'Viveros forestales y recolección de productos forestales',
#        'Captación, tratamiento y suministro de agua',
#        'Servicios de arquitectura, ingeniería y actividades relacionadas',
#        'Servicios de intermediación para el transporte de carga',
#        'Fabricación de otra maquinaria y equipo para la industria en general',
#        'Otro transporte terrestre de pasajeros',
#        'COMERCIO AL POR MENOR DE ARTICULOS PARA EL CUIDADO DE LA SALUD',
#        'Fabricación de maquinaria y equipo agropecuario, para la construcción y para la industria extractiva',
#        'Pesca', 'EXPLOTACION AVICOLA', 'Edificación residencial',
#        'OTRO TRANSPORTE TERRESTRE DE PASAJEROS',
#        'Agentes y representantes de artistas, deportistas y similares',
#        'Autotransporte de carga especializado',
#        'Fabricación de carrocerías y remolques',
#        'ACABADO DE PRODUCTOS TEXTILES Y FABRICACION DE TELAS RECUBIERTAS',
#        'Explotación de otros animales',
#        'CONSTRUCCION DE VIAS DE COMUNICACION',
#        'INSTITUCIONES FINANCIERAS DE FOMENTO ECONOMICO',
#        'Fabricación de productos metálicos forjados y troquelados',
#        'COMERCIO AL POR MAYOR DE MAQUINARIA Y EQUIPO PARA LA INDUSTRIA',
#        'Industria básica del hierro y del acero',
#        'Comercio al por mayor de materiales de desecho',
#        'Orfanatos y otras residencias de asistencia social',
#        'SERVICIOS DE REVELADO E IMPRESION DE FOTOGRAFIAS Y OTROS SERVICIOS PERSONALES',
#        'SUMINISTRO DE GAS POR DUCTOS AL CONSUMIDOR FINAL',
#        'Escuelas de educación postbachillerato',
#        'MATANZA, EMPACADO Y PROCESAMIENTO DE CARNE DE GANADO, AVES Y OTROS ANIMALES COMESTIBLES',
#        'TRANSPORTE MARITIMO',
#        'SERVICIOS COMBINADOS DE APOYO EN INSTALACIONES',
#        'SALONES Y CLINICAS DE BELLEZA, BAÑOS PUBLICOS Y BOLERIAS',
#        'TRANSPORTE COLECTIVO FORANEO DE PASAJEROS DE RUTA FIJA',
#        'Fabricación de alambre, productos de alambre y resortes',
#        'Otros cultivos', 'CENTROS NOCTURNOS, BARES, CANTINAS Y SIMILARES',
#        'Parques con instalaciones recreativas y casas de juegos electrónicos',
#        'Procesamiento electrónico de información, hospedaje y otros servicios relacionados',
#        'FABRICACION DE EQUIPO DE GENERACION Y DISTRIBUCION DE ENERGIA ELECTRICA',
#        'Elaboración de azúcares, chocolates, dulces y similares',
#        'Operadores de telecomunicaciones inalámbricas, excepto servicios de satélite',
#        'EXTRACCION DE PETROLEO Y GAS',
#        'ACTIVIDADES ADMINISTRATIVAS DE INSTITUCIONES DE BIENESTAR SOCIAL',
#        'Promotores de espectáculos artísticos, culturales, deportivos y similares',
#        'FABRICACION DE OTROS PRODUCTOS DE CUERO, PIEL Y MATERIALES SUCEDANEOS',
#        'COMERCIO AL POR MENOR DE MOBILIARIO, EQUIPO Y ACCESORIOS DE COMPUTO, TELEFONOS Y OTROS APARATOS DE COMUNICACION',
#        'FABRICACION DE VIDRIO Y PRODUCTOS DE VIDRIO',
#        'ORGANISMOS INTERNACIONALES Y EXTRATERRITORIALES',
#        'Extracción de petróleo y gas',
#        'Fabricación de productos farmacéuticos', 'Cultivo de hortalizas',
#        'EDICION DE PERIODICOS, REVISTAS, LIBROS Y SIMILARES, Y EDICION DE ESTAS PUBLICACIONES INTEGRADA CON LA IMPRESION',
#        'Fabricación de equipo de generación y distribución de energía eléctrica',
#        'RECUBRIMIENTOS Y TERMINADOS METALICOS',
#        'Fabricación de computadoras y equipo periférico',
#        'Servicios relacionados con el transporte por agua',
#        'INTERMEDIACION DE COMERCIO AL POR MAYOR EXCLUSIVAMENTE A TRAVES DE INTERNET Y OTROS MEDIOS ELECTRONICOS',
#        'Fabricación de otro equipo de transporte',
#        'Cultivo de semillas oleaginosas, leguminosas y cereales',
#        'División de terrenos y construcción de obras de urbanización',
#        'Servicios relacionados con la agricultura',
#        'FABRICACION DE PARTES PARA VEHICULOS AUTOMOTORES',
#        'CAZA Y CAPTURA',
#        'CULTIVO DE SEMILLAS OLEAGINOSAS, LEGUMINOSAS Y CEREALES',
#        'Fabricación de productos de cartón y papel',
#        'Producción de programación de canales para sistemas de televisión por cable o satelitales',
#        'MINERIA DE MINERALES METALICOS',
#        'Comercio al por menor de artículos usados',
#        'Edición de software y edición de software integrada con la reproducción',
#        'COMERCIO AL POR MENOR DE MOTOCICLETAS Y OTROS VEHICULOS DE MOTOR',
#        'Recubrimientos y terminados metálicos',
#        'TRANSPORTE POR FERROCARRIL',
#        'Fabricación de equipo no electrónico y material desechable de uso médico, dental y para laboratorio, y artículos oftálmicos',
#        'COMERCIO AL POR MAYOR DE PRODUCTOS TEXTILES Y CALZADO',
#        'INMOBILIARIAS Y CORREDORES DE BIENES RAICES',
#        'Transporte por ductos de otros productos',
#        'Explotación de bovinos', 'Explotación de porcinos',
#        'Cultivo en invernaderos y viveros, y floricultura',
#        'COMERCIO AL POR MENOR EXCLUSIVAMENTE A TRAVES DE INTERNET, Y CATALOGOS IMPRESOS, TELEVISION Y SIMILARES',
#        'Fabricación de pinturas, recubrimientos y adhesivos',
#        'LABORATORIOS MEDICOS Y DE DIAGNOSTICO', 'DISEÑO ESPECIALIZADO',
#        'Bolsa de valores', 'Banca múltiple',
#        'Alquiler de autobuses con chofer',
#        'SERVICIOS DE INVESTIGACION, PROTECCION Y SEGURIDAD',
#        'PREPARACION E HILADO DE FIBRAS TEXTILES, Y FABRICACION DE HILOS',
#        'FABRICACION DE LAMINADOS Y AGLUTINADOS DE MADERA',
#        'Fabricación de aparatos eléctricos de uso doméstico',
#        'Artistas, escritores y técnicos independientes',
#        'ESCUELAS DE EDUCACION BASICA, MEDIA Y PARA NECESIDADES ESPECIALES',
#        'SERVICIOS DE ORIENTACION Y TRABAJO SOCIAL', 'BANCA CENTRAL',
#        'COMERCIO AL POR MAYOR DE MAQUINARIA Y EQUIPO PARA LOS SERVICIOS Y PARA ACTIVIDADES COMERCIALES',
#        'INDUSTRIAS DE METALES NO FERROSOS, EXCEPTO ALUMINIO',
#        'Órganos legislativos',
#        'Servicios de mensajería y paquetería foránea',
#        'Confección de alfombras, blancos y similares', 'Acuicultura',
#        'Molienda de granos y de semillas y obtención de aceites y grasas',
#        'ESTACIONAMIENTOS Y PENSIONES PARA VEHICULOS AUTOMOTORES',
#        'COMERCIO AL POR MENOR DE PRODUCTOS TEXTILES, EXCEPTO ROPA',
#        'Otro transporte turístico',
#        'FABRICACION DE INSTRUMENTOS DE MEDICION, CONTROL, NAVEGACION, Y EQUIPO MEDICO ELECTRONICO',
#        'COMERCIO AL POR MENOR DE PARTES Y REFACCIONES PARA AUTOMOVILES, CAMIONETAS Y CAMIONES',
#        'Banca central',
#        'Servicios de alquiler de marcas registradas, patentes y franquicias',
#        'Silvicultura', 'FABRICACION DE CALZADO',
#        'ELABORACION DE PRODUCTOS DE PANADERIA Y TORTILLAS',
#        'OTROS CONSULTORIOS PARA EL CUIDADO DE LA SALUD',
#        'ELABORACION DE ALIMENTOS PARA ANIMALES', 'HOSPITALES GENERALES',
#        'INSTITUCIONES DE SEGUROS Y FIANZAS',
#        'SERVICIOS DE ARQUITECTURA, INGENIERIA Y ACTIVIDADES RELACIONADAS',
#        'REPARACION Y MANTENIMIENTO DE AUTOMOVILES Y CAMIONES',
#        'Asilos y otras residencias para el cuidado de ancianos',
#        'AGENTES Y REPRESENTANTES DE ARTISTAS, DEPORTISTAS Y SIMILARES',
#        'COMERCIO AL POR MAYOR DE CAMIONES Y DE PARTES Y REFACCIONES NUEVAS PARA AUTOMOVILES, CAMIONETAS Y CAMIONES',
#        'FABRICACION DE PRODUCTOS A BASE DE ARCILLAS Y MINERALES REFRACTARIOS',
#        'REPARACION Y MANTENIMIENTO DE ARTICULOS PARA EL HOGAR Y PERSONALES',
#        'Suministro de gas por ductos al consumidor final',
#        'Fabricación de equipo de aire acondicionado, calefacción, y de refrigeración industrial y comercial',
#        'FABRICACION DE EQUIPO DE AUDIO Y DE VIDEO',
#        'FABRICACION DE OTROS EQUIPOS Y ACCESORIOS ELECTRICOS',
#        'Fabricación de productos a base de arcillas y minerales refractarios',
#        'Explotación de ovinos y caprinos',
#        'COMERCIO AL POR MENOR DE COMBUSTIBLES, ACEITES Y GRASAS LUBRICANTES',
#        'FABRICACION DE OTRO EQUIPO DE TRANSPORTE',
#        'FABRICACION DE PRODUCTOS DE HULE',
#        'Servicios relacionados con la intermediación crediticia no bursátil',
#        'Fabricación de maquinaria y equipo para el comercio y los servicios',
#        'Transporte turístico por agua',
#        'Matanza, empacado y procesamiento de carne de ganado, aves y otros animales comestibles',
#        'PROCESAMIENTO ELECTRONICO DE INFORMACION, HOSPEDAJE Y OTROS SERVICIOS RELACIONADOS',
#        'Fabricación de telas', 'INDUSTRIA BASICA DEL ALUMINIO',
#        'CAPTACION, TRATAMIENTO Y SUMINISTRO DE AGUA',
#        'SERVICIOS RELACIONADOS CON EL TRANSPORTE POR CARRETERA',
#        'INSTALACIONES Y EQUIPAMIENTO EN CONSTRUCCIONES',
#        'Centros nocturnos, bares, cantinas y similares',
#        'SERVICIOS RELACIONADOS CON LA INTERMEDIACION CREDITICIA NO BURSATIL',
#        'MANEJO DE DESECHOS Y SERVICIOS DE REMEDIACION',
#        'Industria del tabaco',
#        'FABRICACION DE PINTURAS, RECUBRIMIENTOS Y ADHESIVOS',
#        'ESCUELAS DE EDUCACION POSTBACHILLERATO',
#        'FABRICACION DE ESTRUCTURAS METALICAS Y PRODUCTOS DE HERRERIA',
#        'SERVICIOS RELACIONADOS CON EL APROVECHAMIENTO FORESTAL',
#        'SERVICIOS FUNERARIOS Y ADMINISTRACION DE CEMENTERIOS',
#        'Moldeo por fundición de piezas metálicas',
#        'CONSULTORIOS DENTALES',
#        'COMERCIO AL POR MENOR DE BEBIDAS, HIELO Y TABACO',
#        'Intermediación de comercio al por mayor, excepto a través de internet y de otros medios electrónicos',
#        'EDIFICACION NO RESIDENCIAL',
#        'DIVISION DE TERRENOS Y CONSTRUCCION DE OBRAS DE URBANIZACION',
#        'Servicios postales',
#        'Hospitales psiquiátricos y para el tratamiento por adicción',
#        'CIMENTACIONES, MONTAJE DE ESTRUCTURAS PREFABRICADAS Y TRABAJOS EN EXTERIORES',
#        'ASERRADO Y CONSERVACION DE LA MADERA',
#        'CENTROS PARA LA ATENCION DE PACIENTES QUE NO REQUIEREN HOSPITALIZACION',
#        'Industrias de metales no ferrosos, excepto aluminio',
#        'Estacionamientos y pensiones para vehículos automotores',
#        'SERVICIOS DE INTERMEDIACION PARA EL TRANSPORTE DE CARGA',
#        'Casas de bolsa, casas de cambio y centros cambiarios',
#        'SERVICIOS LEGALES',
#        'SERVICIOS DE TELECOMUNICACIONES POR SATELITE',
#        'Regulación y fomento de actividades para mejorar y preservar el medio ambiente',
#        'CENTROS GENERALES DE ALQUILER',
#        'Fabricación de herramientas de mano sin motor y utensilios de cocina metálicos',
#        'MOLDEO POR FUNDICION DE PIEZAS METALICAS',
#        'Fabricación de cal, yeso y productos de yeso',
#        'Fabricación de colchones, persianas y cortineros',
#        'COMERCIO AL POR MAYOR DE MATERIAS PRIMAS AGROPECUARIAS Y FORESTALES',
#        'ASOCIACIONES Y ORGANIZACIONES RELIGIOSAS, POLITICAS Y CIVILES',
#        'Manejo de desechos y servicios de remediación',
#        'ACTIVIDADES DE SEGURIDAD NACIONAL',
#        'SERVICIOS RELACIONADOS CON LA MINERIA',
#        'COMERCIO AL POR MAYOR DE ELECTRODOMESTICOS MENORES Y APARATOS DE LINEA BLANCA',
#        'Hogares con empleados domésticos',
#        'SERVICIOS RELACIONADOS CON LA AGRICULTURA',
#        'Fabricación de equipo ferroviario',
#        'FABRICACION DE MAQUINARIA Y EQUIPO PARA EL COMERCIO Y LOS SERVICIOS',
#        'Impartición de justicia y mantenimiento de la seguridad y el orden público',
#        'Intermediación de comercio al por mayor exclusivamente a través de internet y otros medios electrónicos',
#        'Casinos, loterías y otros juegos de azar',
#        'Fabricación de accesorios de iluminación',
#        'Fabricación de jabones, limpiadores y preparaciones de tocador',
#        'Transporte marítimo',
#        'FABRICACION DE PRODUCTOS METALICOS FORJADOS Y TROQUELADOS',
#        'SERVICIO DE APOYO SECRETARIAL, FOTOCOPIADO, COBRANZA, INVESTIGACION CREDITICIA Y SIMILARES',
#        'OTRAS INSTITUCIONES DE INTERMEDIACION CREDITICIA Y FINANCIERA NO BURSATIL',
#        'PENSIONES Y CASAS DE HUESPEDES, Y DEPARTAMENTOS Y CASAS AMUEBLADOS CON SERVICIOS DE HOTELERIA',
#        'Minería de minerales metálicos', 'EXPLOTACION DE PORCINOS',
#        'SERVICIOS DE MENSAJERIA Y PAQUETERIA FORANEA',
#        'Generación, transmisión y distribución de energía eléctrica',
#        'FABRICACION DE EQUIPO DE AIRE ACONDICIONADO, CALEFACCION, Y DE REFRIGERACION INDUSTRIAL Y COMERCIAL',
#        'OTROS CULTIVOS',
#        'PARQUES CON INSTALACIONES RECREATIVAS Y CASAS DE JUEGOS ELECTRONICOS',
#        'FABRICACION DE CEMENTO Y PRODUCTOS DE CONCRETO',
#        'FABRICACION DE MAQUINARIA Y EQUIPO AGROPECUARIO, PARA LA CONSTRUCCION Y PARA LA INDUSTRIA EXTRACTIVA',
#        'HOGARES CON EMPLEADOS DOMESTICOS',
#        'FABRICACION DE ACCESORIOS DE ILUMINACION',
#        'ORFANATOS Y OTRAS RESIDENCIAS DE ASISTENCIA SOCIAL',
#        'FABRICACION DE COMPONENTES ELECTRONICOS', 'Relaciones exteriores',
#        'RESIDENCIAS CON CUIDADOS DE ENFERMERAS PARA ENFERMOS CONVALECIENTES, EN REHABILITACION, INCURABLES Y TERMINALES',
#        'FABRICACION DE AUTOMOVILES Y CAMIONES',
#        'SERVICIOS RELACIONADOS CON EL TRANSPORTE AEREO',
#        'ASESORIA EN INVERSIONES Y OTROS SERVICIOS RELACIONADOS CON LA INTERMEDIACION BURSATIL',
#        'FABRICACION DE MUEBLES DE OFICINA Y ESTANTERIA',
#        'OTRO TRANSPORTE TURISTICO',
#        'Organismos internacionales y extraterritoriales',
#        'SERVICIOS DE ALQUILER DE MARCAS REGISTRADAS, PATENTES Y FRANQUICIAS',
#        'SERVICIO DE TAXIS Y LIMUSINAS',
#        'COMERCIO AL POR MAYOR DE MATERIAS PRIMAS PARA LA INDUSTRIA',
#        'INDUSTRIA DEL TABACO',
#        'COMERCIO AL POR MAYOR DE MAQUINARIA Y EQUIPO AGROPECUARIO, FORESTAL Y PARA LA PESCA',
#        'CONSERVACION DE FRUTAS, VERDURAS Y ALIMENTOS PREPARADOS',
#        'SILVICULTURA', 'UNIONES DE CREDITO E INSTITUCIONES DE AHORRO',
#        'FABRICACION DE PRODUCTOS DE HIERRO Y ACERO',
#        'PROMOTORES DE ESPECTACULOS ARTISTICOS, CULTURALES, DEPORTIVOS Y SIMILARES',
#        'OPERADORES DE TELECOMUNICACIONES ALAMBRICAS',
#        'MUSEOS, SITIOS HISTORICOS, ZOOLOGICOS Y SIMILARES',
#        'Transporte aéreo regular',
#        'Operadores de telecomunicaciones alámbricas',
#        'Explotación avícola', 'Transporte aéreo no regular',
#        'Regulación y fomento del desarrollo económico',
#        'Fabricación de productos derivados del petróleo y del carbón',
#        'Transporte de petróleo crudo por ductos',
#        'Fabricación de equipo de audio y de video',
#        'Transporte por aguas interiores', 'Transporte por ferrocarril',
#        'Fabricación y reproducción de medios magnéticos y ópticos',
#        'Minería de minerales no metálicos',
#        'Servicios relacionados con la minería',
#        'Fabricación de otros productos a base de minerales no metálicos',
#        'Residencias con cuidados de enfermeras para enfermos convalecientes, en rehabilitación, incurables y terminales',
#        'BANCA MULTIPLE', 'TRANSPORTE ESCOLAR Y DE PERSONAL',
#        'SERVICIOS DE AMBULANCIAS, DE BANCOS DE ORGANOS Y OTROS SERVICIOS AUXILIARES AL TRATAMIENTO MEDICO',
#        'CASINOS, LOTERIAS Y OTROS JUEGOS DE AZAR',
#        'ELABORACION DE AZUCARES, CHOCOLATES, DULCES Y SIMILARES',
#        'MINERIA DE MINERALES NO METALICOS',
#        'TRANSMISION DE PROGRAMAS DE RADIO Y TELEVISION',
#        'SERVICIOS RELACIONADOS CON EL TRANSPORTE POR AGUA',
#        'ALQUILER DE AUTOMOVILES, CAMIONES Y OTROS TRANSPORTES TERRESTRES',
#        'AGENCIAS DE VIAJES Y SERVICIOS DE RESERVACIONES',
#        'SERVICIOS DE ENFERMERIA A DOMICILIO',
#        'COMERCIO AL POR MENOR DE CALZADO',
#        'TRANSPORTE POR DUCTOS DE OTROS PRODUCTOS',
#        'DEPORTISTAS Y EQUIPOS DEPORTIVOS PROFESIONALES', 'GUARDERIAS',
#        'SERVICIOS DE CAPACITACION PARA EL TRABAJO PARA PERSONAS DESEMPLEADAS, SUBEMPLEADAS O DISCAPACITADAS',
#        'COMERCIO AL POR MENOR DE ARTICULOS DE PERFUMERIA Y JOYERIA',
#        'SERVICIOS DE PUBLICIDAD Y ACTIVIDADES RELACIONADAS',
#        'ESCUELAS DE OFICIOS',
#        'COMERCIO AL POR MAYOR DE MATERIALES DE DESECHO',
#        'ESCUELAS COMERCIALES, DE COMPUTACION Y DE CAPACITACION PARA EJECUTIVOS',
#        'COMERCIO AL POR MAYOR DE DISCOS, JUGUETES Y ARTICULOS DEPORTIVOS',
#        'COMPAÑIAS Y GRUPOS DE ESPECTACULOS ARTISTICOS Y CULTURALES',
#        'TRANSPORTE TURISTICO POR TIERRA',
#        'FABRICACION DE JABONES, LIMPIADORES Y PREPARACIONES DE TOCADOR',
#        'FABRICACION DE EQUIPO NO ELECTRONICO Y MATERIAL DESECHABLE DE USO MEDICO, DENTAL Y PARA LABORATORIO, Y ARTICULOS OFTALMICOS',
#        'COMERCIO AL POR MENOR DE ARTICULOS USADOS',
#        'CULTIVO EN INVERNADEROS Y VIVEROS, Y FLORICULTURA',
#        'ASILOS Y OTRAS RESIDENCIAS PARA EL CUIDADO DE ANCIANOS',
#        'FABRICACION DE MOTORES DE COMBUSTION INTERNA, TURBINAS Y TRANSMISIONES',
#        'SERVICIOS POSTALES',
#        'RESIDENCIAS PARA EL CUIDADO DE PERSONAS CON PROBLEMAS DE RETARDO MENTAL, TRASTORNO MENTAL Y ADICCIONES',
#        'FABRICACION DE APARATOS ELECTRICOS DE USO DOMESTICO',
#        'FABRICACION DE CALDERAS, TANQUES Y ENVASES METALICOS',
#        'ACUICULTURA',
#        'SERVICIOS RELACIONADOS CON LA CRIA Y EXPLOTACION DE ANIMALES',
#        'MOLIENDA DE GRANOS Y DE SEMILLAS Y OBTENCION DE ACEITES Y GRASAS',
#        'FABRICACION DE MAQUINARIA Y EQUIPO PARA LAS INDUSTRIAS MANUFACTURERAS, EXCEPTO LA METALMECANICA',
#        'CONFECCION DE ALFOMBRAS, BLANCOS Y SIMILARES',
#        'TRANSPORTE COLECTIVO URBANO Y SUBURBANO DE PASAJEROS DE RUTA FIJA',
#        'CULTIVO DE FRUTALES Y NUECES', 'RELACIONES EXTERIORES',
#        'CONFECCION DE ACCESORIOS DE VESTIR Y OTRAS PRENDAS DE VESTIR NO CLASIFICADOS EN OTRA PARTE',
#        'IMPARTICION DE JUSTICIA Y MANTENIMIENTO DE LA SEGURIDAD Y EL ORDEN PUBLICO',
#        'PREPARACION Y ENVASADO DE PESCADOS Y MARISCOS',
#        'COMERCIO AL POR MENOR DE MASCOTAS, REGALOS, ARTICULOS RELIGIOSOS, DESECHABLES Y OTROS ARTICULOS DE USO PERSONAL',
#        'VIVEROS FORESTALES Y RECOLECCION DE PRODUCTOS FORESTALES',
#        'ALQUILER DE ARTICULOS PARA EL HOGAR Y PERSONALES',
#        'FABRICACION DE CARROCERIAS Y REMOLQUES',
#        'CASAS DE BOLSA, CASAS DE CAMBIO Y CENTROS CAMBIARIOS',
#        'HOSPITALES PSIQUIATRICOS Y PARA EL TRATAMIENTO POR ADICCION',
#        'FABRICACION DE FERTILIZANTES, PESTICIDAS Y OTROS AGROQUIMICOS',
#        'FABRICACION DE ALAMBRE, PRODUCTOS DE ALAMBRE Y RESORTES',
#        'FABRICACION DE HERRAJES Y CERRADURAS',
#        'FABRICACION DE EQUIPO AEROESPACIAL', 'CULTIVO DE HORTALIZAS',
#        'FABRICACION DE OTROS PRODUCTOS A BASE DE MINERALES NO METALICOS',
#        'TRANSPORTE DE GAS NATURAL POR DUCTOS',
#        'CURTIDO Y ACABADO DE CUERO Y PIEL',
#        'PRODUCCION DE PROGRAMACION DE CANALES PARA SISTEMAS DE TELEVISION POR CABLE O SATELITALES',
#        'FABRICACION DE CAL, YESO Y PRODUCTOS DE YESO',
#        'SERVICIOS RELACIONADOS CON EL TRANSPORTE POR FERROCARRIL',
#        'ALQUILER SIN INTERMEDIACION DE BIENES RAICES', 'BOLSA DE VALORES',
#        'REGULACION Y FOMENTO DE ACTIVIDADES PARA MEJORAR Y PRESERVAR EL MEDIO AMBIENTE',
#        'FABRICACION DE EQUIPO FERROVIARIO',
#        'TRANSPORTE TURISTICO POR AGUA', 'INDUSTRIA DEL SONIDO', 'PESCA',
#        'INDUSTRIA FILMICA Y DEL VIDEO',
#        'ALQUILER DE AUTOBUSES CON CHOFER',
#        'FABRICACION DE HERRAMIENTAS DE MANO SIN MOTOR Y UTENSILIOS DE COCINA METALICOS',
#        'FABRICACION DE EQUIPO DE COMUNICACION',
#        'MINERIA DE CARBON MINERAL',
#        'FABRICACION DE COLCHONES, PERSIANAS Y CORTINEROS',
#        'TRANSPORTE AEREO NO REGULAR', 'ORGANOS LEGISLATIVOS',
#        'REGULACION Y FOMENTO DEL DESARROLLO ECONOMICO',
#        'EXPLOTACION DE OVINOS Y CAPRINOS',
#        'ARTISTAS, ESCRITORES Y TECNICOS INDEPENDIENTES',
#        'CAMPAMENTOS Y ALBERGUES RECREATIVOS',
#        'TRANSPORTE POR AGUAS INTERIORES', 'EXPLOTACION DE OTROS ANIMALES',
#        'FABRICACION DE EMBARCACIONES', '-',
#        'FABRICACION Y REPRODUCCION DE MEDIOS MAGNETICOS Y OPTICOS',
#        'TALA DE ARBOLES'], dtype=object)

# %%
empresas['tipo_empleador'].unique()
# Out:
# array(['PRIVADA', 'PÚBLICA', 'SOCIAL'], dtype=object)

# %%
empresas_clean = empresas.copy()

# %% [markdown]
# ## Assesment and cleaning

# %%
empresas_clean['id_empresa'] =  empresas_clean['id_empresa'].astype(int)

# %%
# Verify new datatype
empresas_clean.id_empresa.dtype
# Out:
# dtype('int64')

# %%
empresas_clean.actividad = empresas.actividad.str.title()

# %%
empresas_clean.actividad.nunique()
# Out:
# 507

# %%
empresas_clean.actividad.unique()
# Out:
# array(['Servicios De Contabilidad, Auditoría Y Servicios Relacionados',
#        'Servicios De Administración De Negocios',
#        'Servicios De Publicidad Y Actividades Relacionadas',
#        'Servicios Legales',
#        'Otros Servicios Relacionados Con El Transporte',
#        'Industria Del Sonido', 'Guarderías',
#        'Comercio Al Por Mayor De Abarrotes Y Alimentos',
#        'Comercio Al Por Menor En Tiendas De Autoservicio',
#        'Agencias De Viajes Y Servicios De Reservaciones',
#        'Escuelas De Educación Básica, Media Y Para Necesidades Especiales',
#        'Servicios De Almacenamiento', 'Curtido Y Acabado De Cuero Y Piel',
#        'Comercio Al Por Menor De Abarrotes Y Alimentos',
#        'Salones Y Clínicas De Belleza, Baños Públicos Y Bolerías',
#        'Fabricacion De Prendas De Vestir De Punto',
#        'Otros Servicios De Apoyo A Los Negocios',
#        'Servicios De Investigacion Cientifica Y Desarrollo',
#        'Confección De Prendas De Vestir', 'Consultorios Medicos',
#        'Otras Industrias Alimentarias',
#        'Otros Servicios De Telecomunicaciones', 'Edificacion Residencial',
#        'Alquiler De Artículos Para El Hogar Y Personales',
#        'Consultorios Dentales',
#        'Comercio Al Por Menor De Mobiliario, Equipo Y Accesorios De Cómputo, Teléfonos Y Otros Aparatos De Comunicación',
#        'Comercio Al Por Menor De Partes Y Refacciones Para Automóviles, Camionetas Y Camiones',
#        'Servicios De Investigación Científica Y Desarrollo',
#        'Impresión E Industrias Conexas',
#        'Reparación Y Mantenimiento De Artículos Para El Hogar Y Personales',
#        'Otros Servicios Educativos',
#        'Servicios De Contabilidad, Auditoria Y Servicios Relacionados',
#        'Servicios De Consultoría Administrativa, Científica Y Técnica',
#        'Reparación Y Mantenimiento De Equipo Electrónico Y De Equipo De Precisión',
#        'Corporativos', 'Restaurantes Con Servicio Completo',
#        'Transporte Colectivo Foráneo De Pasajeros De Ruta Fija',
#        'Servicios Relacionados Con El Transporte Por Ferrocarril',
#        'Comercio Al Por Menor De Artículos De Ferretería, Tlapalería Y Vidrios',
#        'Comercio Al Por Mayor De Materias Primas Para La Industria',
#        'Comercio Al Por Menor De Artículos De Papelería, Libros, Revistas Y Periódicos',
#        'Otros Servicios Profesionales, Cientificos Y Tecnicos',
#        'Servicios Relacionados Con Los Seguros Y Las Fianzas',
#        'Intermediacion De Comercio Al Por Mayor, Excepto A Traves De Internet Y De Otros Medios Electronicos',
#        'Comercio Al Por Mayor De Mobiliario Y Equipo De Cómputo Y De Oficina, Y De Otra Maquinaria Y Equipo De Uso General',
#        'Alquiler De Maquinaria Y Equipo Agropecuario, Pesquero, Industrial, Comercial Y De Servicios',
#        'Asociaciones Y Organizaciones Comerciales, Laborales, Profesionales Y Recreativas',
#        'Fabricación De Cemento Y Productos De Concreto',
#        'Fabricacion De Productos Quimicos Basicos',
#        'Servicios De Administracion De Negocios',
#        'Fabricación De Laminados Y Aglutinados De Madera',
#        'Fabricación De Prendas De Vestir De Punto',
#        'Fabricacion De Resinas Y Hules Sinteticos, Y Fibras Quimicas',
#        'Comercio Al Por Mayor De Productos Textiles Y Calzado',
#        'Servicios De Apoyo A La Educación',
#        'Construccion De Obras Para El Suministro De Agua, Petroleo, Gas, Energia Electrica Y Telecomunicaciones',
#        'Fabricacion De Otra Maquinaria Y Equipo Para La Industria En General',
#        'Otros Servicios Recreativos',
#        'Autotransporte De Carga Especializado',
#        'Fabricación De Muebles, Excepto De Oficina Y Estantería',
#        'Comercio Al Por Mayor De Artículos De Papelería, Libros, Revistas Y Periódicos',
#        'Servicios Relacionados Con La Cría Y Explotación De Animales',
#        'Escuelas Comerciales, De Computación Y De Capacitación Para Ejecutivos',
#        'Servicios Funerarios Y Administración De Cementerios',
#        'Fabricación De Muebles De Oficina Y Estantería',
#        'Servicio De Apoyo Secretarial, Fotocopiado, Cobranza, Investigación Crediticia Y Similares',
#        'Fabricacion De Productos De Carton Y Papel',
#        'Hoteles, Moteles Y Similares',
#        'Servicios De Capacitación Para El Trabajo Para Personas Desempleadas, Subempleadas O Discapacitadas',
#        'Fabricación De Equipo Aeroespacial',
#        'Comercio Al Por Menor De Artículos Para El Cuidado De La Salud',
#        'Trabajos De Acabados En Edificaciones',
#        'Servicios De Investigación, Protección Y Seguridad',
#        'Laboratorios Médicos Y De Diagnóstico',
#        'Comercio Al Por Mayor De Artículos De Perfumería, Cosméticos Y Joyería',
#        'Servicios De Revelado E Impresión De Fotografías Y Otros Servicios Personales',
#        'Fabricación De Calderas, Tanques Y Envases Metálicos',
#        'Fabricación De Partes Para Vehículos Automotores',
#        'Comercio Al Por Menor De Mascotas, Regalos, Artículos Religiosos, Desechables Y Otros Artículos De Uso Personal',
#        'Escuelas De Educación Superior',
#        'Fabricación De Automóviles Y Camiones', 'Fabricacion De Telas',
#        'Escuelas De Oficios',
#        'Reparación Y Mantenimiento De Automóviles Y Camiones',
#        'Comercio Al Por Menor En Tiendas Departamentales',
#        'Fabricacion De Otros Productos Metalicos',
#        'Confección De Accesorios De Vestir Y Otras Prendas De Vestir No Clasificados En Otra Parte',
#        'Elaboración De Productos Lácteos',
#        'Comercio Al Por Mayor De Articulos De Papeleria, Libros, Revistas Y Periodicos',
#        'Servicios De Consultoria Administrativa, Cientifica Y Tecnica',
#        'Servicios De Apoyo A La Educacion',
#        'Comercio Al Por Menor De Ropa, Bisutería Y Accesorios De Vestir',
#        'Otros Servicios Profesionales, Científicos Y Técnicos',
#        'Inmobiliarias Y Corredores De Bienes Raíces',
#        'Comercio Al Por Menor De Motocicletas Y Otros Vehículos De Motor',
#        'Maquinado De Piezas Metalicas Y Fabricacion De Tornillos',
#        'Servicios De Limpieza',
#        'Comercio Al Por Menor De Articulos Para El Esparcimiento',
#        'Administración Pública En General',
#        'Servicios De Diseño De Sistemas De Cómputo Y Servicios Relacionados',
#        'Consultorios Médicos', 'Fabricacion De Pulpa, Papel Y Carton',
#        'Reparacion Y Mantenimiento De Maquinaria Y Equipo Agropecuario, Industrial, Comercial Y De Servicios',
#        'Fabricación De Otros Productos Metálicos',
#        'Administracion Publica En General',
#        'Comercio Al Por Menor De Muebles Para El Hogar Y Otros Enseres Domésticos',
#        'Servicios De Enfermería A Domicilio',
#        'Edicion De Software Y Edicion De Software Integrada Con La Reproduccion',
#        'Restaurantes De Autoservicio, Comida Para Llevar Y Otros Restaurantes Con Servicio Limitado',
#        'Comercio Al Por Mayor De Productos Farmacéuticos',
#        'Autotransporte De Carga General', 'Diseño Especializado',
#        'Otras Industrias Manufactureras',
#        'Comercio Al Por Mayor De Articulos De Perfumeria, Cosmeticos Y Joyeria',
#        'Comercio Al Por Menor De Articulos De Ferreteria, Tlapaleria Y Vidrios',
#        'Operadores De Telecomunicaciones Inalambricas, Excepto Servicios De Satelite',
#        'Comercio Al Por Mayor De Productos Farmaceuticos',
#        'Otras Instituciones De Intermediación Crediticia Y Financiera No Bursátil',
#        'Otros Consultorios Para El Cuidado De La Salud',
#        'Comercio Al Por Mayor De Mobiliario Y Equipo De Computo Y De Oficina, Y De Otra Maquinaria Y Equipo De Uso General',
#        'Industria De Las Bebidas',
#        'Reparación Y Mantenimiento De Maquinaria Y Equipo Agropecuario, Industrial, Comercial Y De Servicios',
#        'Elaboración De Productos De Panadería Y Tortillas',
#        'Fabricacion De Otros Productos Textiles, Excepto Prendas De Vestir',
#        'Comercio Al Por Menor De Calzado',
#        'Fabricacion De Productos De Plastico',
#        'Comercio Al Por Menor De Artículos Para La Decoración De Interiores',
#        'Construcción De Obras Para El Suministro De Agua, Petróleo, Gas, Energía Eléctrica Y Telecomunicaciones',
#        'Comercio Al Por Menor De Combustibles, Aceites Y Grasas Lubricantes',
#        'Impresion E Industrias Conexas',
#        'Transporte Colectivo Urbano Y Suburbano De Pasajeros De Ruta Fija',
#        'Comercio Al Por Mayor De Discos, Juguetes Y Artículos Deportivos',
#        'Comercio Al Por Mayor De Electrodomésticos Menores Y Aparatos De Línea Blanca',
#        'Fabricación De Productos Químicos Básicos',
#        'Fabricacion De Computadoras Y Equipo Periferico',
#        'Servicios Relacionados Con Los Servicios Inmobiliarios',
#        'Fabricación De Otros Productos De Madera',
#        'Otras Construcciones De Ingenieria Civil',
#        'Comercio Al Por Menor De Bebidas, Hielo Y Tabaco',
#        'Generacion, Transmision Y Distribucion De Energia Electrica',
#        'Fabricacion De Otros Productos De Madera',
#        'Instalaciones Y Equipamiento En Construcciones',
#        'Comercio Al Por Mayor De Maquinaria Y Equipo Agropecuario, Forestal Y Para La Pesca',
#        'Hospitales De Otras Especialidades Medicas',
#        'Instituciones Financieras De Fomento Económico',
#        'Otras Construcciones De Ingeniería Civil',
#        'Comercio Al Por Mayor De Bebidas, Hielo Y Tabaco',
#        'Fabricación De Pulpa, Papel Y Cartón',
#        'Comercio Al Por Menor De Articulos De Papeleria, Libros, Revistas Y Periodicos',
#        'Comercio Al Por Menor De Artículos De Perfumería Y Joyería',
#        'Fabricación De Vidrio Y Productos De Vidrio',
#        'Comercio Al Por Menor Exclusivamente A Través De Internet, Y Catálogos Impresos, Televisión Y Similares',
#        'Servicios De Empleo', 'Instituciones De Seguros Y Fianzas',
#        'Comercio Al Por Menor De Artículos Para El Esparcimiento',
#        'Fabricación De Productos De Plástico',
#        'Lavanderias Y Tintorerias', 'Otros Servicios De Información',
#        'Industria Básica Del Aluminio',
#        'Servicios De Diseño De Sistemas De Computo Y Servicios Relacionados',
#        'Fabricación De Otros Productos Textiles, Excepto Prendas De Vestir',
#        'Fabricación De Resinas Y Hules Sintéticos, Y Fibras Químicas',
#        'Servicios De Orientación Y Trabajo Social',
#        'Comercio Al Por Mayor De Camiones Y De Partes Y Refacciones Nuevas Para Automóviles, Camionetas Y Camiones',
#        'Construcción De Vías De Comunicación',
#        'Edición De Periódicos, Revistas, Libros Y Similares, Y Edición De Estas Publicaciones Integrada Con La Impresión',
#        'Otros Servicios De Informacion',
#        'Museos, Sitios Históricos, Zoológicos Y Similares',
#        'Otros Trabajos Especializados Para La Construccion',
#        'Confeccion De Prendas De Vestir',
#        'Fabricacion De Maquinaria Y Equipo Para La Industria Metalmecanica',
#        'Industria Basica Del Hierro Y Del Acero',
#        'Servicio De Taxis Y Limusinas',
#        'Pensiones Y Casas De Huéspedes, Y Departamentos Y Casas Amueblados Con Servicios De Hotelería',
#        'Comercio Al Por Mayor De Maquinaria Y Equipo Para Los Servicios Y Para Actividades Comerciales',
#        'Fabricación De Calzado',
#        'Comercio Al Por Menor De Productos Textiles, Excepto Ropa',
#        'Fabricacion De Productos Farmaceuticos',
#        'Fabricación De Productos De Hule',
#        'Servicios Relacionados Con El Transporte Aéreo',
#        'Cimentaciones, Montaje De Estructuras Prefabricadas Y Trabajos En Exteriores',
#        'Explotacion De Bovinos',
#        'Fabricación De Componentes Electrónicos',
#        'Fabricación De Maquinaria Y Equipo Para La Industria Metalmecánica',
#        'Elaboración De Alimentos Para Animales',
#        'Reparacion Y Mantenimiento De Equipo Electronico Y De Equipo De Precision',
#        'Comercio Al Por Mayor De Maquinaria Y Equipo Para La Industria',
#        'Centros Generales De Alquiler',
#        'Servicios De Mensajeria Y Paqueteria Local',
#        'Campamentos Y Albergues Recreativos',
#        'Fabricación De Estructuras Metálicas Y Productos De Herrería',
#        'Servicios De Telecomunicaciones Por Satélite',
#        'Cultivo De Frutales Y Nueces',
#        'Fabricación De Productos De Hierro Y Acero',
#        'Actividades Administrativas De Instituciones De Bienestar Social',
#        'Servicios Comunitarios De Alimentación, Refugio Y Emergencia',
#        'Otros Trabajos Especializados Para La Construcción',
#        'Comercio Al Por Menor De Automóviles Y Camionetas',
#        'Servicios De Preparacion De Alimentos Por Encargo',
#        'Lavanderías Y Tintorerías',
#        'Transmisión De Programas De Radio Y Televisión',
#        'Comercio Al Por Menor De Automoviles Y Camionetas',
#        'Conservación De Frutas, Verduras Y Alimentos Preparados',
#        'Hospitales Generales', 'Elaboracion De Productos Lacteos',
#        'Transporte Aereo Regular',
#        'Maquinado De Piezas Metálicas Y Fabricación De Tornillos',
#        'Alquiler Sin Intermediación De Bienes Raíces',
#        'Servicios Relacionados Con El Transporte Por Carretera',
#        'Servicios Comunitarios De Alimentacion, Refugio Y Emergencia',
#        'Preparación E Hilado De Fibras Textiles, Y Fabricación De Hilos',
#        'Fabricación De Herrajes Y Cerraduras',
#        'Servicios De Ambulancias, De Bancos De Órganos Y Otros Servicios Auxiliares Al Tratamiento Médico',
#        'Fabricacion De Productos Derivados Del Petroleo Y Del Carbon',
#        'Industria Fílmica Y Del Video',
#        'Fabricación De Otros Productos Químicos',
#        'Edificación No Residencial',
#        'Comercio Al Por Menor De Muebles Para El Hogar Y Otros Enseres Domesticos',
#        'Servicios Combinados De Apoyo En Instalaciones',
#        'Centros Para La Atención De Pacientes Que No Requieren Hospitalización',
#        'Fabricación De Equipo De Comunicación',
#        'Servicios De Preparación De Alimentos Por Encargo',
#        'Comercio Al Por Menor De Articulos Para La Decoracion De Interiores',
#        'Fabricación De Maquinaria Y Equipo Para Las Industrias Manufactureras, Excepto La Metalmecánica',
#        'Fabricacion De Otros Productos Quimicos',
#        'Escuelas De Educacion Superior',
#        'Servicios Relacionados Con El Aprovechamiento Forestal',
#        'Alquiler De Automóviles, Camiones Y Otros Transportes Terrestres',
#        'Transporte Escolar Y De Personal',
#        'Asesoría En Inversiones Y Otros Servicios Relacionados Con La Intermediación Bursátil',
#        'Transporte Turístico Por Tierra',
#        'Fabricación De Otros Equipos Y Accesorios Eléctricos',
#        'Comercio Al Por Mayor De Materias Primas Agropecuarias Y Forestales',
#        'Fabricacion De Muebles, Excepto De Oficina Y Estanteria',
#        'Comercio Al Por Menor De Ropa, Bisuteria Y Accesorios De Vestir',
#        'Aserrado Y Conservación De La Madera',
#        'Actividades De Seguridad Nacional',
#        'Acabado De Productos Textiles Y Fabricación De Telas Recubiertas',
#        'Hospitales De Otras Especialidades Médicas',
#        'Asociaciones Y Organizaciones Religiosas, Políticas Y Civiles',
#        'Compañías Y Grupos De Espectáculos Artísticos Y Culturales',
#        'Fabricación De Fertilizantes, Pesticidas Y Otros Agroquímicos',
#        'Preparación Y Envasado De Pescados Y Mariscos',
#        'Fabricación De Otros Productos De Cuero, Piel Y Materiales Sucedáneos',
#        'Deportistas Y Equipos Deportivos Profesionales',
#        'Servicios De Mensajería Y Paquetería Local',
#        'Uniones De Crédito E Instituciones De Ahorro',
#        'Viveros Forestales Y Recolección De Productos Forestales',
#        'Captación, Tratamiento Y Suministro De Agua',
#        'Servicios De Arquitectura, Ingeniería Y Actividades Relacionadas',
#        'Servicios De Intermediación Para El Transporte De Carga',
#        'Fabricación De Otra Maquinaria Y Equipo Para La Industria En General',
#        'Otro Transporte Terrestre De Pasajeros',
#        'Comercio Al Por Menor De Articulos Para El Cuidado De La Salud',
#        'Fabricación De Maquinaria Y Equipo Agropecuario, Para La Construcción Y Para La Industria Extractiva',
#        'Pesca', 'Explotacion Avicola', 'Edificación Residencial',
#        'Agentes Y Representantes De Artistas, Deportistas Y Similares',
#        'Fabricación De Carrocerías Y Remolques',
#        'Acabado De Productos Textiles Y Fabricacion De Telas Recubiertas',
#        'Explotación De Otros Animales',
#        'Construccion De Vias De Comunicacion',
#        'Instituciones Financieras De Fomento Economico',
#        'Fabricación De Productos Metálicos Forjados Y Troquelados',
#        'Industria Básica Del Hierro Y Del Acero',
#        'Comercio Al Por Mayor De Materiales De Desecho',
#        'Orfanatos Y Otras Residencias De Asistencia Social',
#        'Servicios De Revelado E Impresion De Fotografias Y Otros Servicios Personales',
#        'Suministro De Gas Por Ductos Al Consumidor Final',
#        'Escuelas De Educación Postbachillerato',
#        'Matanza, Empacado Y Procesamiento De Carne De Ganado, Aves Y Otros Animales Comestibles',
#        'Transporte Maritimo',
#        'Salones Y Clinicas De Belleza, Baños Publicos Y Bolerias',
#        'Transporte Colectivo Foraneo De Pasajeros De Ruta Fija',
#        'Fabricación De Alambre, Productos De Alambre Y Resortes',
#        'Otros Cultivos', 'Centros Nocturnos, Bares, Cantinas Y Similares',
#        'Parques Con Instalaciones Recreativas Y Casas De Juegos Electrónicos',
#        'Procesamiento Electrónico De Información, Hospedaje Y Otros Servicios Relacionados',
#        'Fabricacion De Equipo De Generacion Y Distribucion De Energia Electrica',
#        'Elaboración De Azúcares, Chocolates, Dulces Y Similares',
#        'Operadores De Telecomunicaciones Inalámbricas, Excepto Servicios De Satélite',
#        'Extraccion De Petroleo Y Gas',
#        'Promotores De Espectáculos Artísticos, Culturales, Deportivos Y Similares',
#        'Fabricacion De Otros Productos De Cuero, Piel Y Materiales Sucedaneos',
#        'Comercio Al Por Menor De Mobiliario, Equipo Y Accesorios De Computo, Telefonos Y Otros Aparatos De Comunicacion',
#        'Fabricacion De Vidrio Y Productos De Vidrio',
#        'Organismos Internacionales Y Extraterritoriales',
#        'Extracción De Petróleo Y Gas',
#        'Fabricación De Productos Farmacéuticos', 'Cultivo De Hortalizas',
#        'Edicion De Periodicos, Revistas, Libros Y Similares, Y Edicion De Estas Publicaciones Integrada Con La Impresion',
#        'Fabricación De Equipo De Generación Y Distribución De Energía Eléctrica',
#        'Recubrimientos Y Terminados Metalicos',
#        'Fabricación De Computadoras Y Equipo Periférico',
#        'Servicios Relacionados Con El Transporte Por Agua',
#        'Intermediacion De Comercio Al Por Mayor Exclusivamente A Traves De Internet Y Otros Medios Electronicos',
#        'Fabricación De Otro Equipo De Transporte',
#        'Cultivo De Semillas Oleaginosas, Leguminosas Y Cereales',
#        'División De Terrenos Y Construcción De Obras De Urbanización',
#        'Servicios Relacionados Con La Agricultura',
#        'Fabricacion De Partes Para Vehiculos Automotores',
#        'Caza Y Captura', 'Fabricación De Productos De Cartón Y Papel',
#        'Producción De Programación De Canales Para Sistemas De Televisión Por Cable O Satelitales',
#        'Mineria De Minerales Metalicos',
#        'Comercio Al Por Menor De Artículos Usados',
#        'Edición De Software Y Edición De Software Integrada Con La Reproducción',
#        'Comercio Al Por Menor De Motocicletas Y Otros Vehiculos De Motor',
#        'Recubrimientos Y Terminados Metálicos',
#        'Transporte Por Ferrocarril',
#        'Fabricación De Equipo No Electrónico Y Material Desechable De Uso Médico, Dental Y Para Laboratorio, Y Artículos Oftálmicos',
#        'Inmobiliarias Y Corredores De Bienes Raices',
#        'Transporte Por Ductos De Otros Productos',
#        'Explotación De Bovinos', 'Explotación De Porcinos',
#        'Cultivo En Invernaderos Y Viveros, Y Floricultura',
#        'Comercio Al Por Menor Exclusivamente A Traves De Internet, Y Catalogos Impresos, Television Y Similares',
#        'Fabricación De Pinturas, Recubrimientos Y Adhesivos',
#        'Laboratorios Medicos Y De Diagnostico', 'Bolsa De Valores',
#        'Banca Múltiple', 'Alquiler De Autobuses Con Chofer',
#        'Servicios De Investigacion, Proteccion Y Seguridad',
#        'Preparacion E Hilado De Fibras Textiles, Y Fabricacion De Hilos',
#        'Fabricacion De Laminados Y Aglutinados De Madera',
#        'Fabricación De Aparatos Eléctricos De Uso Doméstico',
#        'Artistas, Escritores Y Técnicos Independientes',
#        'Escuelas De Educacion Basica, Media Y Para Necesidades Especiales',
#        'Servicios De Orientacion Y Trabajo Social', 'Banca Central',
#        'Industrias De Metales No Ferrosos, Excepto Aluminio',
#        'Órganos Legislativos',
#        'Servicios De Mensajería Y Paquetería Foránea',
#        'Confección De Alfombras, Blancos Y Similares', 'Acuicultura',
#        'Molienda De Granos Y De Semillas Y Obtención De Aceites Y Grasas',
#        'Estacionamientos Y Pensiones Para Vehiculos Automotores',
#        'Otro Transporte Turístico',
#        'Fabricacion De Instrumentos De Medicion, Control, Navegacion, Y Equipo Medico Electronico',
#        'Comercio Al Por Menor De Partes Y Refacciones Para Automoviles, Camionetas Y Camiones',
#        'Servicios De Alquiler De Marcas Registradas, Patentes Y Franquicias',
#        'Silvicultura', 'Fabricacion De Calzado',
#        'Elaboracion De Productos De Panaderia Y Tortillas',
#        'Elaboracion De Alimentos Para Animales',
#        'Servicios De Arquitectura, Ingenieria Y Actividades Relacionadas',
#        'Reparacion Y Mantenimiento De Automoviles Y Camiones',
#        'Asilos Y Otras Residencias Para El Cuidado De Ancianos',
#        'Comercio Al Por Mayor De Camiones Y De Partes Y Refacciones Nuevas Para Automoviles, Camionetas Y Camiones',
#        'Fabricacion De Productos A Base De Arcillas Y Minerales Refractarios',
#        'Reparacion Y Mantenimiento De Articulos Para El Hogar Y Personales',
#        'Fabricación De Equipo De Aire Acondicionado, Calefacción, Y De Refrigeración Industrial Y Comercial',
#        'Fabricacion De Equipo De Audio Y De Video',
#        'Fabricacion De Otros Equipos Y Accesorios Electricos',
#        'Fabricación De Productos A Base De Arcillas Y Minerales Refractarios',
#        'Explotación De Ovinos Y Caprinos',
#        'Fabricacion De Otro Equipo De Transporte',
#        'Fabricacion De Productos De Hule',
#        'Servicios Relacionados Con La Intermediación Crediticia No Bursátil',
#        'Fabricación De Maquinaria Y Equipo Para El Comercio Y Los Servicios',
#        'Transporte Turístico Por Agua',
#        'Procesamiento Electronico De Informacion, Hospedaje Y Otros Servicios Relacionados',
#        'Fabricación De Telas', 'Industria Basica Del Aluminio',
#        'Captacion, Tratamiento Y Suministro De Agua',
#        'Servicios Relacionados Con La Intermediacion Crediticia No Bursatil',
#        'Manejo De Desechos Y Servicios De Remediacion',
#        'Industria Del Tabaco',
#        'Fabricacion De Pinturas, Recubrimientos Y Adhesivos',
#        'Escuelas De Educacion Postbachillerato',
#        'Fabricacion De Estructuras Metalicas Y Productos De Herreria',
#        'Servicios Funerarios Y Administracion De Cementerios',
#        'Moldeo Por Fundición De Piezas Metálicas',
#        'Intermediación De Comercio Al Por Mayor, Excepto A Través De Internet Y De Otros Medios Electrónicos',
#        'Edificacion No Residencial',
#        'Division De Terrenos Y Construccion De Obras De Urbanizacion',
#        'Servicios Postales',
#        'Hospitales Psiquiátricos Y Para El Tratamiento Por Adicción',
#        'Aserrado Y Conservacion De La Madera',
#        'Centros Para La Atencion De Pacientes Que No Requieren Hospitalizacion',
#        'Estacionamientos Y Pensiones Para Vehículos Automotores',
#        'Servicios De Intermediacion Para El Transporte De Carga',
#        'Casas De Bolsa, Casas De Cambio Y Centros Cambiarios',
#        'Servicios De Telecomunicaciones Por Satelite',
#        'Regulación Y Fomento De Actividades Para Mejorar Y Preservar El Medio Ambiente',
#        'Fabricación De Herramientas De Mano Sin Motor Y Utensilios De Cocina Metálicos',
#        'Moldeo Por Fundicion De Piezas Metalicas',
#        'Fabricación De Cal, Yeso Y Productos De Yeso',
#        'Fabricación De Colchones, Persianas Y Cortineros',
#        'Asociaciones Y Organizaciones Religiosas, Politicas Y Civiles',
#        'Manejo De Desechos Y Servicios De Remediación',
#        'Servicios Relacionados Con La Mineria',
#        'Comercio Al Por Mayor De Electrodomesticos Menores Y Aparatos De Linea Blanca',
#        'Hogares Con Empleados Domésticos',
#        'Fabricación De Equipo Ferroviario',
#        'Fabricacion De Maquinaria Y Equipo Para El Comercio Y Los Servicios',
#        'Impartición De Justicia Y Mantenimiento De La Seguridad Y El Orden Público',
#        'Intermediación De Comercio Al Por Mayor Exclusivamente A Través De Internet Y Otros Medios Electrónicos',
#        'Casinos, Loterías Y Otros Juegos De Azar',
#        'Fabricación De Accesorios De Iluminación',
#        'Fabricación De Jabones, Limpiadores Y Preparaciones De Tocador',
#        'Transporte Marítimo',
#        'Fabricacion De Productos Metalicos Forjados Y Troquelados',
#        'Servicio De Apoyo Secretarial, Fotocopiado, Cobranza, Investigacion Crediticia Y Similares',
#        'Otras Instituciones De Intermediacion Crediticia Y Financiera No Bursatil',
#        'Pensiones Y Casas De Huespedes, Y Departamentos Y Casas Amueblados Con Servicios De Hoteleria',
#        'Minería De Minerales Metálicos', 'Explotacion De Porcinos',
#        'Servicios De Mensajeria Y Paqueteria Foranea',
#        'Generación, Transmisión Y Distribución De Energía Eléctrica',
#        'Fabricacion De Equipo De Aire Acondicionado, Calefaccion, Y De Refrigeracion Industrial Y Comercial',
#        'Parques Con Instalaciones Recreativas Y Casas De Juegos Electronicos',
#        'Fabricacion De Cemento Y Productos De Concreto',
#        'Fabricacion De Maquinaria Y Equipo Agropecuario, Para La Construccion Y Para La Industria Extractiva',
#        'Hogares Con Empleados Domesticos',
#        'Fabricacion De Accesorios De Iluminacion',
#        'Fabricacion De Componentes Electronicos', 'Relaciones Exteriores',
#        'Residencias Con Cuidados De Enfermeras Para Enfermos Convalecientes, En Rehabilitacion, Incurables Y Terminales',
#        'Fabricacion De Automoviles Y Camiones',
#        'Servicios Relacionados Con El Transporte Aereo',
#        'Asesoria En Inversiones Y Otros Servicios Relacionados Con La Intermediacion Bursatil',
#        'Fabricacion De Muebles De Oficina Y Estanteria',
#        'Otro Transporte Turistico',
#        'Conservacion De Frutas, Verduras Y Alimentos Preparados',
#        'Uniones De Credito E Instituciones De Ahorro',
#        'Fabricacion De Productos De Hierro Y Acero',
#        'Promotores De Espectaculos Artisticos, Culturales, Deportivos Y Similares',
#        'Operadores De Telecomunicaciones Alambricas',
#        'Museos, Sitios Historicos, Zoologicos Y Similares',
#        'Transporte Aéreo Regular',
#        'Operadores De Telecomunicaciones Alámbricas',
#        'Explotación Avícola', 'Transporte Aéreo No Regular',
#        'Regulación Y Fomento Del Desarrollo Económico',
#        'Fabricación De Productos Derivados Del Petróleo Y Del Carbón',
#        'Transporte De Petróleo Crudo Por Ductos',
#        'Fabricación De Equipo De Audio Y De Video',
#        'Transporte Por Aguas Interiores',
#        'Fabricación Y Reproducción De Medios Magnéticos Y Ópticos',
#        'Minería De Minerales No Metálicos',
#        'Servicios Relacionados Con La Minería',
#        'Fabricación De Otros Productos A Base De Minerales No Metálicos',
#        'Residencias Con Cuidados De Enfermeras Para Enfermos Convalecientes, En Rehabilitación, Incurables Y Terminales',
#        'Banca Multiple',
#        'Servicios De Ambulancias, De Bancos De Organos Y Otros Servicios Auxiliares Al Tratamiento Medico',
#        'Casinos, Loterias Y Otros Juegos De Azar',
#        'Elaboracion De Azucares, Chocolates, Dulces Y Similares',
#        'Mineria De Minerales No Metalicos',
#        'Transmision De Programas De Radio Y Television',
#        'Alquiler De Automoviles, Camiones Y Otros Transportes Terrestres',
#        'Servicios De Enfermeria A Domicilio', 'Guarderias',
#        'Servicios De Capacitacion Para El Trabajo Para Personas Desempleadas, Subempleadas O Discapacitadas',
#        'Comercio Al Por Menor De Articulos De Perfumeria Y Joyeria',
#        'Escuelas Comerciales, De Computacion Y De Capacitacion Para Ejecutivos',
#        'Comercio Al Por Mayor De Discos, Juguetes Y Articulos Deportivos',
#        'Compañias Y Grupos De Espectaculos Artisticos Y Culturales',
#        'Transporte Turistico Por Tierra',
#        'Fabricacion De Jabones, Limpiadores Y Preparaciones De Tocador',
#        'Fabricacion De Equipo No Electronico Y Material Desechable De Uso Medico, Dental Y Para Laboratorio, Y Articulos Oftalmicos',
#        'Comercio Al Por Menor De Articulos Usados',
#        'Fabricacion De Motores De Combustion Interna, Turbinas Y Transmisiones',
#        'Residencias Para El Cuidado De Personas Con Problemas De Retardo Mental, Trastorno Mental Y Adicciones',
#        'Fabricacion De Aparatos Electricos De Uso Domestico',
#        'Fabricacion De Calderas, Tanques Y Envases Metalicos',
#        'Servicios Relacionados Con La Cria Y Explotacion De Animales',
#        'Molienda De Granos Y De Semillas Y Obtencion De Aceites Y Grasas',
#        'Fabricacion De Maquinaria Y Equipo Para Las Industrias Manufactureras, Excepto La Metalmecanica',
#        'Confeccion De Alfombras, Blancos Y Similares',
#        'Confeccion De Accesorios De Vestir Y Otras Prendas De Vestir No Clasificados En Otra Parte',
#        'Imparticion De Justicia Y Mantenimiento De La Seguridad Y El Orden Publico',
#        'Preparacion Y Envasado De Pescados Y Mariscos',
#        'Comercio Al Por Menor De Mascotas, Regalos, Articulos Religiosos, Desechables Y Otros Articulos De Uso Personal',
#        'Viveros Forestales Y Recoleccion De Productos Forestales',
#        'Alquiler De Articulos Para El Hogar Y Personales',
#        'Fabricacion De Carrocerias Y Remolques',
#        'Hospitales Psiquiatricos Y Para El Tratamiento Por Adiccion',
#        'Fabricacion De Fertilizantes, Pesticidas Y Otros Agroquimicos',
#        'Fabricacion De Alambre, Productos De Alambre Y Resortes',
#        'Fabricacion De Herrajes Y Cerraduras',
#        'Fabricacion De Equipo Aeroespacial',
#        'Fabricacion De Otros Productos A Base De Minerales No Metalicos',
#        'Transporte De Gas Natural Por Ductos',
#        'Produccion De Programacion De Canales Para Sistemas De Television Por Cable O Satelitales',
#        'Fabricacion De Cal, Yeso Y Productos De Yeso',
#        'Alquiler Sin Intermediacion De Bienes Raices',
#        'Regulacion Y Fomento De Actividades Para Mejorar Y Preservar El Medio Ambiente',
#        'Fabricacion De Equipo Ferroviario',
#        'Transporte Turistico Por Agua', 'Industria Filmica Y Del Video',
#        'Fabricacion De Herramientas De Mano Sin Motor Y Utensilios De Cocina Metalicos',
#        'Fabricacion De Equipo De Comunicacion',
#        'Mineria De Carbon Mineral',
#        'Fabricacion De Colchones, Persianas Y Cortineros',
#        'Transporte Aereo No Regular', 'Organos Legislativos',
#        'Regulacion Y Fomento Del Desarrollo Economico',
#        'Explotacion De Ovinos Y Caprinos',
#        'Artistas, Escritores Y Tecnicos Independientes',
#        'Explotacion De Otros Animales', 'Fabricacion De Embarcaciones',
#        '-', 'Fabricacion Y Reproduccion De Medios Magneticos Y Opticos',
#        'Tala De Arboles'], dtype=object)

# %% [markdown]
# ## Storing data

# %%
empresas_clean.to_csv('empresas_clean.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Analysis and visualization

# %%
empresas_clean['como_se_entero_del_sne'].value_counts().plot(kind = 'pie', startangle=90, autopct='%1.1f%%')
plt.axis('square')
plt.title('¿Cómo se enteró del SNE?')
plt.ylabel('');

# %%
empresas_clean.head()

# %%
descripcion_empresas_count = empresas_clean['descripcion_empresa'].value_counts()
top_10_empresas = descripcion_empresas_count.nlargest(10)

# %%
top_10_empresas

# %%
top_10_empresas.plot(kind = 'barh', figsize=(10,5))
plt.title('¿Cuál es la actividad de la empresa?')
plt.xlabel('Número de empresas')
xticklocs = np.arange(100, 101, 1000) #(start of interval, end of interval, spacing between values)
xticknames = [1,2,3,4,5]
plt.xticks(xticklocs, xticknames);

# %%
empresas['tipo_persona'].unique()

# %%
empresas_clean['tipo_persona'].value_counts().plot(kind = 'pie', startangle=90, autopct='%1.1f%%')
plt.axis('square')
plt.title('Razón social del empleador')
plt.ylabel('');

# %%
empresas['tipo_sociedad'].unique()

# %%
tipo_sociedad_count = empresas_clean['tipo_sociedad'].value_counts()
top_10_tipo_sociedad = tipo_sociedad_count.nlargest(10)

# %%
top_10_tipo_sociedad.plot(kind = 'barh', figsize=(10,5))
plt.title('Tipo de sociedad de la empresa')
plt.xlabel('Número de empresas')
xticklocs = np.arange(100, 101, 1000) #(start of interval, end of interval, spacing between values)
xticknames = [1,2,3,4,5]
plt.xticks(xticklocs, xticknames);

# %%
empresas['descripcion_empresa'].unique()

# %%
descripcion_empresa_count = empresas_clean['descripcion_empresa'].value_counts()
top_10_descripcion_empresa = descripcion_empresa_count.nlargest(10)

# %%
top_10_descripcion_empresa.plot(kind = 'barh', figsize=(10,5))
plt.title('Descripcion del giro de la empresa')
plt.xlabel('Número de empresas')
xticklocs = np.arange(100, 101, 1000) #(start of interval, end of interval, spacing between values)
xticknames = [1,2,3,4,5]
plt.xticks(xticklocs, xticknames);

# %%
empresas['tipo_empleador'].unique()

# %%
empresas_clean['tipo_empleador'].value_counts().plot(kind = 'pie', startangle=90, autopct='%1.1f%%')
plt.axis('square')
plt.title('Tipo de sector de la empresa')
plt.ylabel('');

# %%
empresas['entidadfed_sne'].unique()

# %%
entidadfed_sne_count = empresas_clean['entidadfed_sne'].value_counts()

# %%
entidadfed_sne_count.plot(kind = 'barh', figsize=(10,5))
plt.title('Entidad federativa donde se registró la empresa')
plt.xlabel('Número de empresas')
xticklocs = np.arange(100, 101, 1000) #(start of interval, end of interval, spacing between values)
xticknames = [1,2,3,4,5]
plt.xticks(xticklocs, xticknames);

# %%
empresas['como_se_entero_del_sne'].unique()

# %%
como_se_entero_del_sne_count = empresas_clean['como_se_entero_del_sne'].value_counts()

# %%
como_se_entero_del_sne_count .plot(kind = 'barh', figsize=(10,5))
plt.title('Entidad federativa donde se registró la vacante')
plt.xlabel('Número de empresas')
xticklocs = np.arange(100, 101, 1000) #(start of interval, end of interval, spacing between values)
xticknames = [1,2,3,4,5]
plt.xticks(xticklocs, xticknames);
